# %%
import os
import random
import tkinter as tk
from tkinter import messagebox

# Function to generate a random password
def generate_password():
    try:
        length = int(length_entry.get())
        char_pool = ""
        if use_uppercase.get():
            char_pool += "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        if use_lowercase.get():
            char_pool += "abcdefghijklmnopqrstuvwxyz"
        if use_digits.get():
            char_pool += "0123456789"
        if use_symbols.get():
            char_pool += "!@#$%^&*()-_=+[]{}|;:',.<>?/"

        if not char_pool:
            messagebox.showwarning("Warning", "Select at least one character set!")
            return
        
        password = ''.join(random.choice(char_pool) for _ in range(length))
        password_entry.delete(0, tk.END)
        password_entry.insert(0, password)
    except ValueError:
        messagebox.showerror("Error", "Enter a valid number for length.")

# Function to copy password to clipboard
def copy_to_clipboard():
    root.clipboard_clear()
    root.clipboard_append(password_entry.get())
    root.update()
    messagebox.showinfo("Copied", "Password copied to clipboard!")

# GUI Setup
root = tk.Tk()
root.title("Random Password Generator")

# Widgets
tk.Label(root, text="Password Length:").grid(row=0, column=0, padx=10, pady=5)
length_entry = tk.Entry(root)
length_entry.grid(row=0, column=1, padx=10, pady=5)

use_uppercase = tk.BooleanVar()
tk.Checkbutton(root, text="Include Uppercase", variable=use_uppercase).grid(row=1, column=0, columnspan=2)

use_lowercase = tk.BooleanVar()
tk.Checkbutton(root, text="Include Lowercase", variable=use_lowercase).grid(row=2, column=0, columnspan=2)

use_digits = tk.BooleanVar()
tk.Checkbutton(root, text="Include Digits", variable=use_digits).grid(row=3, column=0, columnspan=2)

use_symbols = tk.BooleanVar()
tk.Checkbutton(root, text="Include Symbols", variable=use_symbols).grid(row=4, column=0, columnspan=2)

tk.Button(root, text="Generate Password", command=generate_password).grid(row=5, column=0, columnspan=2, pady=10)
password_entry = tk.Entry(root, width=30)
password_entry.grid(row=6, column=0, columnspan=2, pady=5)
tk.Button(root, text="Copy to Clipboard", command=copy_to_clipboard).grid(row=7, column=0, columnspan=2, pady=10)

root.mainloop()

# %%
# 88import os
import random
import tkinter as tk
from tkinter import ttk, messagebox

# Function to generate a random password
def generate_password():
    try:
        length = int(length_entry.get())
        char_pool = ""
        if use_uppercase.get():
            char_pool += "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        if use_lowercase.get():
            char_pool += "abcdefghijklmnopqrstuvwxyz"
        if use_digits.get():
            char_pool += "0123456789"
        if use_symbols.get():
            char_pool += "!@#$%^&*()-_=+[]{}|;:',.<>?/"

        if not char_pool:
            messagebox.showwarning("Warning", "Select at least one character set!")
            return
        
        password = ''.join(random.choice(char_pool) for _ in range(length))
        password_entry.delete(0, tk.END)
        password_entry.insert(0, password)
    except ValueError:
        messagebox.showerror("Error", "Enter a valid number for length.")

# Function to copy password to clipboard
def copy_to_clipboard():
    root.clipboard_clear()
    root.clipboard_append(password_entry.get())
    root.update()
    messagebox.showinfo("Copied", "Password copied to clipboard!")

# GUI Setup
root = tk.Tk()
root.title("Random Password Generator")
root.geometry("400x400")
root.resizable(False, False)

# Style
style = ttk.Style()
style.configure("TLabel", font=("Helvetica", 12))
style.configure("TButton", font=("Helvetica", 12))
style.configure("TCheckbutton", font=("Helvetica", 10))

# Frame
frame = ttk.Frame(root, padding="20")
frame.grid(row=0, column=0, sticky="NSEW")

# Widgets
ttk.Label(frame, text="Password Length:").grid(row=0, column=0, padx=5, pady=10, sticky="W")
length_entry = ttk.Entry(frame, width=10)
length_entry.grid(row=0, column=1, padx=5, pady=10, sticky="W")

use_uppercase = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Uppercase", variable=use_uppercase).grid(row=1, column=0, columnspan=2, sticky="W")

use_lowercase = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Lowercase", variable=use_lowercase).grid(row=2, column=0, columnspan=2, sticky="W")

use_digits = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Digits", variable=use_digits).grid(row=3, column=0, columnspan=2, sticky="W")

use_symbols = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Symbols", variable=use_symbols).grid(row=4, column=0, columnspan=2, sticky="W")

ttk.Button(frame, text="Generate Password", command=generate_password).grid(row=5, column=0, columnspan=2, pady=20)
password_entry = ttk.Entry(frame, width=30, font=("Helvetica", 12))
password_entry.grid(row=6, column=0, columnspan=2, pady=10)
ttk.Button(frame, text="Copy to Clipboard", command=copy_to_clipboard).grid(row=7, column=0, columnspan=2, pady=10)

# Add padding around widgets
for child in frame.winfo_children():
    child.grid_configure(padx=5, pady=5)

# Start the application
root.mainloop()
import os
import random
import tkinter as tk
from tkinter import ttk, messagebox

# Function to generate a random password
def generate_password():
    try:
        length = int(length_entry.get())
        char_pool = ""
        if use_uppercase.get():
            char_pool += "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        if use_lowercase.get():
            char_pool += "abcdefghijklmnopqrstuvwxyz"
        if use_digits.get():
            char_pool += "0123456789"
        if use_symbols.get():
            char_pool += "!@#$%^&*()-_=+[]{}|;:',.<>?/"

        if not char_pool:
            messagebox.showwarning("Warning", "Select at least one character set!")
            return
        
        password = ''.join(random.choice(char_pool) for _ in range(length))
        password_entry.delete(0, tk.END)
        password_entry.insert(0, password)
    except ValueError:
        messagebox.showerror("Error", "Enter a valid number for length.")

# Function to copy password to clipboard
def copy_to_clipboard():
    root.clipboard_clear()
    root.clipboard_append(password_entry.get())
    root.update()
    messagebox.showinfo("Copied", "Password copied to clipboard!")

# GUI Setup
root = tk.Tk()
root.title("Random Password Generator")
root.geometry("400x400")
root.resizable(False, False)

# Style
style = ttk.Style()
style.configure("TLabel", font=("Helvetica", 12))
style.configure("TButton", font=("Helvetica", 12))
style.configure("TCheckbutton", font=("Helvetica", 10))

# Frame
frame = ttk.Frame(root, padding="20")
frame.grid(row=0, column=0, sticky="NSEW")

# Widgets
ttk.Label(frame, text="Password Length:").grid(row=0, column=0, padx=5, pady=10, sticky="W")
length_entry = ttk.Entry(frame, width=10)
length_entry.grid(row=0, column=1, padx=5, pady=10, sticky="W")

use_uppercase = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Uppercase", variable=use_uppercase).grid(row=1, column=0, columnspan=2, sticky="W")

use_lowercase = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Lowercase", variable=use_lowercase).grid(row=2, column=0, columnspan=2, sticky="W")

use_digits = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Digits", variable=use_digits).grid(row=3, column=0, columnspan=2, sticky="W")

use_symbols = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Symbols", variable=use_symbols).grid(row=4, column=0, columnspan=2, sticky="W")

ttk.Button(frame, text="Generate Password", command=generate_password).grid(row=5, column=0, columnspan=2, pady=20)
password_entry = ttk.Entry(frame, width=30, font=("Helvetica", 12))
password_entry.grid(row=6, column=0, columnspan=2, pady=10)
ttk.Button(frame, text="Copy to Clipboard", command=copy_to_clipboard).grid(row=7, column=0, columnspan=2, pady=10)

# Add padding around widgets
for child in frame.winfo_children():
    child.grid_configure(padx=5, pady=5)

# Start the application
root.mainloop()

# %% [markdown]
# *I am Planning to change the layout and i will use ttk widgets tkinter library*

# %%
import os
import random
import tkinter as tk
from tkinter import ttk, messagebox

# Function to generate a random password
def generate_password():
    try:
        length = int(length_entry.get())
        char_pool = ""
        if use_uppercase.get():
            char_pool += "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
        if use_lowercase.get():
            char_pool += "abcdefghijklmnopqrstuvwxyz"
        if use_digits.get():
            char_pool += "0123456789"
        if use_symbols.get():
            char_pool += "!@#$%^&*()-_=+[]{}|;:',.<>?/"

        if not char_pool:
            messagebox.showwarning("Warning", "Select at least one character set!")
            return
        
        password = ''.join(random.choice(char_pool) for _ in range(length))
        password_entry.delete(0, tk.END)
        password_entry.insert(0, password)
    except ValueError:
        messagebox.showerror("Error", "Enter a valid number for length.")

# Function to copy password to clipboard
def copy_to_clipboard():
    root.clipboard_clear()
    root.clipboard_append(password_entry.get())
    root.update()
    messagebox.showinfo("Copied", "Password copied to clipboard!")

# GUI Setup
root = tk.Tk()
root.title("Random Password Generator")
root.geometry("400x400")
root.resizable(False, False)

# Style
style = ttk.Style()
style.configure("TLabel", font=("Helvetica", 12))
style.configure("TButton", font=("Helvetica", 12))
style.configure("TCheckbutton", font=("Helvetica", 10))

# Frame
frame = ttk.Frame(root, padding="20")
frame.grid(row=0, column=0, sticky="NSEW")

# Widgets
ttk.Label(frame, text="Password Length:").grid(row=0, column=0, padx=5, pady=10, sticky="W")
length_entry = ttk.Entry(frame, width=10)
length_entry.grid(row=0, column=1, padx=5, pady=10, sticky="W")

use_uppercase = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Uppercase", variable=use_uppercase).grid(row=1, column=0, columnspan=2, sticky="W")

use_lowercase = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Lowercase", variable=use_lowercase).grid(row=2, column=0, columnspan=2, sticky="W")

use_digits = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Digits", variable=use_digits).grid(row=3, column=0, columnspan=2, sticky="W")

use_symbols = tk.BooleanVar()
ttk.Checkbutton(frame, text="Include Symbols", variable=use_symbols).grid(row=4, column=0, columnspan=2, sticky="W")

ttk.Button(frame, text="Generate Password", command=generate_password).grid(row=5, column=0, columnspan=2, pady=20)
password_entry = ttk.Entry(frame, width=30, font=("Helvetica", 12))
password_entry.grid(row=6, column=0, columnspan=2, pady=10)
ttk.Button(frame, text="Copy to Clipboard", command=copy_to_clipboard).grid(row=7, column=0, columnspan=2, pady=10)

# Add padding around widgets
for child in frame.winfo_children():
    child.grid_configure(padx=5, pady=5)

# Start the application
root.mainloop()
